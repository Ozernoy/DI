# %% [markdown]
# # 🌟 Exercise 1 : Basic Usage of SciPy
# Instructions
# Import the SciPy library and explore its version.

# %%
import scipy

scipy_version = scipy.__version__
scipy_version
# Out:
# '1.13.1'

# %% [markdown]
# # 🌟 Exercise 2 : Descriptive Statistics
# Instructions
# Given a sample dataset, calculate the mean, median, variance, and standard deviation using SciPy.
# Sample dataset in code:
# ```python
# data = [12, 15, 13, 12, 18, 20, 22, 21]
# ```

# %%
import numpy as np
from scipy import stats

data = [12, 15, 13, 12, 18, 20, 22, 21]


scipy_stats = stats.describe(data)


mean = scipy_stats.mean
variance = scipy_stats.variance
std_dev = np.sqrt(variance)  # Standard deviation is the square root of variance
median = np.median(data)

mean, median, variance, std_dev
# Out:
# (16.625, 16.5, 17.125, 4.138236339311712)

# %% [markdown]
# # 🌟 Exercise 3 : Understanding Distributions
# Instructions
# Generate a normal distribution using SciPy with a mean of 50 and a standard deviation of 10. Plot this distribution.

# %%
import matplotlib.pyplot as plt

mean, std_dev = 50, 10

data_normal = np.random.normal(mean, std_dev, 1000)

plt.figure(figsize=(8, 6))
plt.hist(data_normal, bins=30, density=True, alpha=0.6, color='b', edgecolor='black')
plt.title('Normal Distribution with Mean = 50 and Std Dev = 10')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# # 🌟 Exercise 4 : T-Test Application
# Instructions
# Perform a T-test on two sets of randomly generated data. Hint: Use numpy.random.normal() to generate the datasets.

# %%
from scipy import stats

data1 = np.random.normal(50, 10, 100)  # Mean = 50, Std = 10, 100 samples
data2 = np.random.normal(55, 12, 100)  # Mean = 55, Std = 12, 100 samples

t_stat, p_value = stats.ttest_ind(data1, data2)

t_stat, p_value
# Out:
# (-2.7617463150311132, 0.006290346317046488)

# %% [markdown]
# # 🌟 Exercise 5 : Working with DataFrames
# Instructions
# Task: Import a dataset using Pandas and calculate descriptive statistics for a specific column using SciPy.
#
# Sample Dataset: Use any publicly available dataset (e.g., Iris dataset).
#
# Code Example:
#
#
# ```PYTHON
# import pandas as pd
#
# df = pd.read_csv('path_to_iris_dataset.csv')
#
# # complete your code here
# ```

# %%
import pandas as pd

# 🌟 Exercise 5: Working with DataFrames
# Loading the Iris dataset from a public source
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)

# Displaying the first few rows of the dataset to understand its structure
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from scipy import stats

scipy_stats = stats.describe(df['sepal_length'])

scipy_stats
# Out:
# DescribeResult(nobs=150, minmax=(4.3, 7.9), mean=5.843333333333334, variance=0.6856935123042507, skewness=0.3117530585022963, kurtosis=-0.5735679489249765)

# %% [markdown]
# # 🌟 Exercise 6 : Advanced Statistical Functions
# Instructions
# Task: Explore one advanced statistical function in SciPy and demonstrate its use with an example.
#
# Sample Task: Calculate kurtosis and skewness of a dataset.
#
# Code Example:
#
#
# ```python
# data = np.random.normal(0, 1, 1000)
#
# # complete your code here
# ```

# %%
data = df['sepal_length']

kurtosis_value = stats.kurtosis(data)
skewness_value = stats.skew(data)

kurtosis_value, skewness_value
# Out:
# (-0.5735679489249765, 0.3117530585022963)
